# %%
import tensorflow as tf
from tensorflow import keras 
import pandas as pd
import seaborn as sns
data=pd.read_csv('/content/drive/My Drive/data_deep_learning/advanced_house_holding_prices.csv')
data.head()

data.isnull().sum()
#data.info()

data=data.drop(['Id','Alley','PoolQC','MiscFeature','Fence'],axis=1)
data.head()


#data.isnull().sum().head(40)
data.LotFrontage.head(90)
data['LotFrontage'].fillna(data['LotFrontage'].median(),inplace=True)

data.isnull().sum().head(40)
data.head()

data['BsmtQual'].value_counts()

data['BsmtQual'].fillna(data['BsmtQual'].mode()[0],inplace=True)
data['BsmtCond'].fillna(data['BsmtCond'].mode()[0],inplace=True)
#data.info()
#sns.heatmap(data.isnull(),yticklabels=False,cbar=False)
data.isnull().sum().head(50)
data['MasVnrType'].value_counts()
#data.head()
data['MasVnrType'].fillna(data['MasVnrType'].mode()[0],inplace=True)
data['MasVnrArea'].value_counts()
data['MasVnrArea'].fillna(data['MasVnrArea'].mode()[0],inplace=True)
data.isnull().sum().head(60)
data['BsmtExposure'].value_counts()
data['BsmtExposure'].fillna(data['BsmtExposure'].mode()[0],inplace=True)
data.isnull().sum().head(60)
data['BsmtFinType1'].value_counts()
data['BsmtFinType1'].fillna(data['BsmtFinType1'].mode()[0],inplace=True)
data['BsmtFinType2'].fillna(data['BsmtFinType2'].mode()[0],inplace=True)
data.isnull().sum().head(60)
data['FireplaceQu'].fillna(data['FireplaceQu'].mode()[0],inplace=True)

data.isnull().sum().head(61)
data['GarageType'].value_counts()
data['GarageType'].fillna(data['GarageType'].mode()[0],inplace=True)

data['GarageYrBlt'].value_counts()
data['GarageYrBlt'].fillna(data['GarageYrBlt'].mode()[0],inplace=True)

data.isnull().sum().head(61)
data['GarageFinish'].value_counts()


data.isnull().sum().head(61)
data['GarageFinish'].fillna(data['GarageFinish'].mode()[0],inplace=True)

#data.info()
data['GarageQual'].value_counts()

data['GarageQual'].fillna(data['GarageQual'].mode()[0],inplace=True)

data['GarageCond'].value_counts()
data['GarageCond'].fillna(data['GarageCond'].mode()[0],inplace=True)
#data.info()
#sns.heatmap(data.isnull(),yticklabels=False,cbar=False)
data.dropna(how='any',inplace=True)
x=data.drop(['SalePrice'],axis=1)
y=data['SalePrice']

#print(y)

x.head()

x.shape

columns=['MSZoning','Street','LotShape','LandContour','Utilities','LotConfig','LandSlope','Neighborhood',
         'Condition2','BldgType','Condition1','HouseStyle','SaleType',
        'SaleCondition','ExterCond',
         'ExterQual','Foundation','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2',
        'RoofStyle','RoofMatl','Exterior1st','Exterior2nd','MasVnrType','Heating','HeatingQC',
         'CentralAir',
         'Electrical','KitchenQual','Functional',
         'FireplaceQu','GarageType','GarageFinish','GarageQual','GarageCond','PavedDrive']
print(len(columns))         
x.head()
from sklearn.preprocessing import LabelEncoder
#label=LabelEncoder()

for feature in columns:
    label=LabelEncoder()
    x[feature]=label.fit_transform(x[feature])
    x=pd.get_dummies(x,drop_first=True,columns=[feature])

x.head()
x.shape
from sklearn.feature_selection import VarianceThreshold
constant=VarianceThreshold(0)
x=constant.fit_transform(x)
x.shape
filter=VarianceThreshold(0.01)
x=filter.fit_transform(x)
x.shape

x_T=x.T
x_T.shape

#from sklearn.model_selection import train_test_split
#x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.01,random_state=0)
#x_train.shape
#x_test.shape
#x_train_T=pd.DataFrame(x_train_T)
#x_test_T=pd.DataFrame(x_test_T)
#x_train_T.duplicated().sum()
#duplicated_features=x_train_T.duplicated()
#duplicated_feature=x_test_T.duplicated()
#duplicated_features
#features_to_keep=[not index for index in duplicated_features]
#feature_to_keep=[not index for index in duplicated_feature]

#features_to_keep


#x_train=x_train_T.T
#x_test=x_test_T[features_to_keep].T
x_T=pd.DataFrame(x_T)
x_T.duplicated().sum()
x=x_T.T
x.shape
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.01,random_state=0)
x_train.shape

from sklearn.preprocessing import StandardScaler
scale=StandardScaler()
x_train=scale.fit_transform(x_train)
x_test=scale.transform(x_test)

import xgboost
classifier=xgboost.XGBRegressor()
classifier.fit(x_train,y_train)
prediction=classifier.predict(x_test)
print(y_test)
print(prediction)
# Out:
# 39
# [10:55:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 1420    179900
# 494      91300
# 1412     90000
# 569     135960
# 486     156000
# 54      130000
# 148     141000
# 1191    174000
# 915      75000
# 427     109008
# 646      98300
# 1305    325000
# 1376     91000
# 501     226700
# 1256    301500
# Name: SalePrice, dtype: int64
# [159215.1    93810.     92513.586 137683.52  145586.33  121915.01
#  161807.81  190825.38   84085.586 115267.29  101983.22  309168.34
#  107968.04  209629.58  338017.56 ]
