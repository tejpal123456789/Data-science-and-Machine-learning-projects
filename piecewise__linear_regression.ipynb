# %% [markdown]
# <a href="https://colab.research.google.com/github/tejpal123456789/Data-science-and-Machine-learning-projects/blob/master/piecewise__linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
#!pip install pwlf
import pwlf
from matplotlib import pyplot as plt
y_train = np.array([1.70, 1.45, 1.50, 1.42, 1.39, 1.90, 2.49, 2.21, 2.57, 2.90, 3.55, 3.80, 4.27, 4.10, 4.60, 4.42, 4.30, 4.52, 4.40, 4.50, 4.15,4.30,4.35], order=None)
x_train = np.array([478, 525, 580,  650,  700,  720,  780,  825,  850,  900,  930,  980, 1020, 1040, 1050, 1075, 1081, 1100, 1160, 1180, 1200,1220,1240], order=None)

x_test=np.linspace(min(x_train),max(x_train),100)
plt.scatter(x_train,y_train)
plt.show()

pwlf=pwlf.PiecewiseLinFit(x_train,y_train)

pwlf_model=pwlf.fit(3)

# %%
y_pred=pwlf.predict(x_test)
plt.scatter(x_train,y_train)
plt.plot(x_test,y_pred)
plt.show()
